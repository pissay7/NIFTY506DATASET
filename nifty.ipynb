# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
os.chdir('D:/Home/mahissa/Downloads/NIFTY50/')

# %%
Nifty = pd.read_csv('NIFTY50-18_23.csv', parse_dates = True )

# %%
print(Nifty.head(10))
# Out:
#           Date      Open      High       Low     Close  Shares_Traded  \
# 0  17-DEC-2018  10853.20  10900.35  10844.85  10888.35    306145514.0
# 1  18-DEC-2018  10850.90  10915.40  10819.10  10908.70    294942271.0
# 2  19-DEC-2018  10930.55  10985.15  10928.00  10967.30    321801803.0
# 3  20-DEC-2018  10885.20  10962.55  10880.05  10951.70    328802751.0
# 4  21-DEC-2018  10944.25  10963.65  10738.65  10754.00    389235107.0
# 5  24-DEC-2018  10780.90  10782.30  10649.25  10663.50    230291344.0
# 6  26-DEC-2018  10635.45  10747.50  10534.55  10729.85    271942701.0
# 7  27-DEC-2018  10817.90  10834.20  10764.45  10779.80    470160392.0
# 8  28-DEC-2018  10820.95  10893.60  10817.15  10859.90    253086507.0
# 9  31-DEC-2018  10913.20  10923.55  10853.20  10862.55    186494657.0
#
#    Turnover
# 0  12528.59
# 1  13556.45
# 2  17172.64
# 3  14945.94
# 4  18663.85
# 5  10695.60
# 6  12831.99
# 7  19119.88
# 8  12615.01
# 9  10176.13

# %%
Nifty['Return'] = (Nifty['Close'] - Nifty['Open']) / Nifty['Open']

# %%
print(Nifty.head(10))
# Out:
#           Date      Open      High       Low     Close  Shares_Traded  \
# 0  17-DEC-2018  10853.20  10900.35  10844.85  10888.35    306145514.0
# 1  18-DEC-2018  10850.90  10915.40  10819.10  10908.70    294942271.0
# 2  19-DEC-2018  10930.55  10985.15  10928.00  10967.30    321801803.0
# 3  20-DEC-2018  10885.20  10962.55  10880.05  10951.70    328802751.0
# 4  21-DEC-2018  10944.25  10963.65  10738.65  10754.00    389235107.0
# 5  24-DEC-2018  10780.90  10782.30  10649.25  10663.50    230291344.0
# 6  26-DEC-2018  10635.45  10747.50  10534.55  10729.85    271942701.0
# 7  27-DEC-2018  10817.90  10834.20  10764.45  10779.80    470160392.0
# 8  28-DEC-2018  10820.95  10893.60  10817.15  10859.90    253086507.0
# 9  31-DEC-2018  10913.20  10923.55  10853.20  10862.55    186494657.0
#
#    Turnover    Return
# 0  12528.59  0.003239
# 1  13556.45  0.005327
# 2  17172.64  0.003362
# 3  14945.94  0.006109
# 4  18663.85 -0.017384
# 5  10695.60 -0.010890
# 6  12831.99  0.008876
# 7  19119.88 -0.003522
# 8  12615.01  0.003599
# 9  10176.13 -0.004641

# %%
ax1 = Nifty['Close'].plot(style = ['-'])
plt.title('Price')
ax1.legend()
plt.plot()
# Out:
# []

# %%
Nifty.plot(subplots = True, figsize=(10, 12))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
ax1 = Nifty['Return'].plot(style = [('-')])
plt.title('Return')
ax1.legend()
plt.plot()
# Out:
# []

# %%
Nifty['Close'].hist()
# Out:
# <Axes: >

# %%
Nifty['Return'].hist()
# Out:
# <Axes: >

# %%
#plot kernel density
Nifty['Return'].plot(kind = 'kde')
plt.show()

# %%
#plot box plot
sns.boxplot(Nifty['Return'])
# Out:
# <Axes: ylabel='Return'>

# %%
#Differencing
Nifty['Close'].diff(1)
# Out:
# Date
# 2018-12-17       NaN
# 2018-12-18     20.35
# 2018-12-19     58.60
# 2018-12-20    -15.60
# 2018-12-21   -197.70
#                ...
# 2023-12-11     27.70
# 2023-12-12    -90.70
# 2023-12-13     19.95
# 2023-12-14    256.35
# 2023-12-15    273.95
# Name: Close, Length: 1240, dtype: float64

# %%
plt.plot(Nifty['Close'].diff(1))

# %%
#resample daily to weekly data
weekly = Nifty.resample('w').mean()

# %%
weekly
# Out:
#                 Open        High         Low       Close  Sharestraded  \
# Date
# 2018-12-23  10892.82  10945.4200  10842.1300  10894.0100   328185489.2
# 2018-12-30  10763.80  10814.4000  10691.3500  10758.2625   306370236.0
# 2019-01-06  10832.05  10859.5200  10737.0500  10792.9500   247680707.6
# 2019-01-13  10829.52  10846.8600  10754.8000  10809.1300   279047392.8
# 2019-01-20  10863.98  10898.3900  10808.7300  10865.3700   296308145.0
# ...              ...         ...         ...         ...           ...
# 2023-11-19  19621.90  19717.2125  19572.2125  19654.0000   250063713.0
# 2023-11-26  19784.82  19823.8200  19736.8000  19777.1900   173833333.6
# 2023-12-03  20030.95  20117.9375  19988.9625  20096.8375   304558678.5
# 2023-12-10  20845.62  20895.2000  20756.9100  20870.0300   345750960.4
# 2023-12-17  21062.29  21143.4400  20974.0200  21093.8400   312246048.4
#
#               Turnover    Return
# Date
# 2018-12-23  15373.4940  0.000131
# 2018-12-30  13815.6200 -0.000484
# 2019-01-06  12752.7660 -0.003602
# 2019-01-13  13498.7860 -0.001880
# 2019-01-20  14063.7540  0.000140
# ...                ...       ...
# 2023-11-19  21551.7975  0.001627
# 2023-11-26  16477.1920 -0.000386
# 2023-12-03  29187.5925  0.003290
# 2023-12-10  32729.6380  0.001182
# 2023-12-17  31036.2260  0.001478
#
# [261 rows x 7 columns]

# %%
plt.plot(weekly['Close'])

# %%
Monthly = Nifty.resample('M').mean()
Monthly
# Out:
#                     Open          High           Low         Close  \
# Date
# 2018-12-31  10843.250000  10890.825000  10782.925000  10836.565000
# 2019-01-31  10828.586957  10861.900000  10750.984783  10809.463043
# 2019-02-28  10841.817500  10891.947500  10781.597500  10833.840000
# 2019-03-31  11300.152632  11350.397368  11253.897368  11317.242105
# 2019-04-30  11681.492105  11722.126316  11616.115789  11666.452632
# ...                  ...           ...           ...           ...
# 2023-08-31  19468.434091  19512.147727  19373.165909  19438.286364
# 2023-09-30  19781.985000  19849.367500  19703.965000  19786.045000
# 2023-10-31  19504.985000  19564.507500  19417.612500  19481.665000
# 2023-11-30  19586.783333  19642.335714  19535.814286  19599.169048
# 2023-12-31  20884.877273  20953.159091  20803.486364  20917.022727
#
#             Sharestraded      Turnover    Return
# Date
# 2018-12-31  3.052903e+08  14230.608000 -0.000592
# 2019-01-31  3.231828e+08  15887.558696 -0.001755
# 2019-02-28  3.730680e+08  17174.890000 -0.000729
# 2019-03-31  3.608994e+08  18151.226842  0.001562
# 2019-04-30  3.429905e+08  17803.451579 -0.001270
# ...                  ...           ...       ...
# 2023-08-31  2.842724e+08  24725.802273 -0.001540
# 2023-09-30  3.038837e+08  25687.309500  0.000228
# 2023-10-31  2.124256e+08  19909.856000 -0.001197
# 2023-11-30  2.106344e+08  19263.890476  0.000621
# 2023-12-31  3.232543e+08  31026.440909  0.001541
#
# [61 rows x 7 columns]

# %%
plt.plot(Monthly['Close'])
